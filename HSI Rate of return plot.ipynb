# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
hsit = yf.Ticker("^HSI")

# get historical market data
hsit = hsit.history(period='5y')

hsit_0=pd.DataFrame(hsit)
hsit_0=hsit_0['Open'][0]

hsit['Change']=hsit.apply(lambda x: x['Close']/hsit_0-1, axis=1)
hsit
# Out:
#                 Open      High       Low     Close      Volume  Dividends  \
# Date
# 2014-12-11  23269.51  23382.83  23169.67  23312.54  2425752500          0
# 2014-12-12  23328.99  23445.96  23230.03  23249.20  1641040200          0
# 2014-12-15  22977.84  23067.67  22856.02  23027.85  1660208200          0
# 2014-12-16  22877.30  22944.28  22641.06  22670.50  2158881100          0
# 2014-12-17  22697.68  22726.56  22529.75  22585.84  2560931200          0
# 2014-12-18  22878.34  22935.05  22736.89  22832.21  2306262800          0
# 2014-12-19  23158.27  23189.60  23041.37  23116.63  2309125300          0
# 2014-12-22  23264.05  23478.90  23264.05  23408.57  2999590500          0
# 2014-12-23  23423.33  23495.62  23269.43  23333.69  1758917300          0
# 2014-12-24  23290.42  23421.10  23290.42  23349.34   740670200          0
# 2014-12-29  23694.53  23867.46  23694.53  23773.18  2133261100          0
# 2014-12-30  23853.13  23853.13  23442.55  23501.10  1768219700          0
# ...

# %%
def pltdata(data, label):
    fig=plt.figure()
    fig.set_size_inches(18.5, 10.5)
    plt.plot(hsit['Change'], linestyle='-', linewidth=1, label='HSI')
    plt.legend()
    plt.show()
pltdata(hsit, 'HSI')
